# %%
import scperturb

# %%
import scanpy

# %%
print(scanpy.__version__)
# Out:
# 1.9.1

# %%
import anndata
print(anndata.__version__)
# Out:
# 0.8.0

# %%
import scanpy as sc

# replace 'path/to/file.h5ad' with the actual path to your file
path = '/Mounts/rbg-storage1/users/johnyang/cellot/datasets/AdamsonWeissman2016_GSM2406681_10X010.h5ad'
adata = sc.read(path)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 65337 × 32738
#     obs: 'perturbation', 'read count', 'UMI count', 'tissue_type', 'cell_line', 'cancer', 'disease', 'perturbation_type', 'celltype', 'organism', 'ncounts', 'ngenes', 'percent_mito', 'percent_ribo', 'nperts'
#     var: 'ensembl_id', 'ncounts', 'ncells'

# %%
adata.obs['perturbation'].value_counts()['*']

# %%
adata.obs[adata.obs['perturbation'] == '*']
# Out:
#                perturbation  read count  UMI count tissue_type cell_line  \
# cell_barcode
# AAGCCAACTTTCGT            *         2.0        1.0   cell_line      K562
# AATGGAGAACCTAG            *         3.0        2.0   cell_line      K562
# ATAGCGTGGTCTGA            *         2.0        1.0   cell_line      K562
# CCTAAACTATTCGG            *         4.0        2.0   cell_line      K562
# GAAGAATGTCCAGA            *        80.0        4.0   cell_line      K562
# ...                     ...         ...        ...         ...       ...
# CGTCGACTCTGTAG            *         2.0        2.0   cell_line      K562
# CTAGGTGACGGGAA            *         1.0        1.0   cell_line      K562
# GAGCTCCTGCGTAT            *         1.0        1.0   cell_line      K562
# GTTAACCTTGGAAA            *         1.0        1.0   cell_line      K562
# TGTTAAGAACCAGT            *         1.0        1.0   cell_line      K562
#
#                 cancer                       disease perturbation_type  \
# cell_barcode
# AAGCCAACTTTCGT    True  chronic myelogenous leukemia            CRISPR
# AATGGAGAACCTAG    True  chronic myelogenous leukemia            CRISPR
# ATAGCGTGGTCTGA    True  chronic myelogenous leukemia            CRISPR
# CCTAAACTATTCGG    True  chronic myelogenous leukemia            CRISPR
# GAAGAATGTCCAGA    True  chronic myelogenous leukemia            CRISPR
# ...                ...                           ...               ...
# CGTCGACTCTGTAG    True  chronic myelogenous leukemia            CRISPR
# CTAGGTGACGGGAA    True  chronic myelogenous leukemia            CRISPR
# GAGCTCCTGCGTAT    True  chronic myelogenous leukemia            CRISPR
# GTTAACCTTGGAAA    True  chronic myelogenous leukemia            CRISPR
# TGTTAAGAACCAGT    True  chronic myelogenous leukemia            CRISPR
#
#                     celltype organism  ncounts  ngenes  percent_mito  \
# cell_barcode
# AAGCCAACTTTCGT  lymphoblasts    human   3653.0    1682      0.054750
# AATGGAGAACCTAG  lymphoblasts    human  10765.0    3503      4.468184
# ATAGCGTGGTCTGA  lymphoblasts    human  12058.0    3381      3.590977
# CCTAAACTATTCGG  lymphoblasts    human  15434.0    3654      4.004147
# GAAGAATGTCCAGA  lymphoblasts    human   7579.0    2730      6.979813
# ...                      ...      ...      ...     ...           ...
# CGTCGACTCTGTAG  lymphoblasts    human  15040.0    3462      5.757979
# CTAGGTGACGGGAA  lymphoblasts    human   8908.0    2861      4.490346
# GAGCTCCTGCGTAT  lymphoblasts    human  10376.0    2978      7.632999
# GTTAACCTTGGAAA  lymphoblasts    human  19693.0    3384      5.997055
# TGTTAAGAACCAGT  lymphoblasts    human  15169.0    3528      7.686729
#
#                 percent_ribo  nperts
# cell_barcode
# AAGCCAACTTTCGT     19.572954       1
# AATGGAGAACCTAG     16.692987       1
# ATAGCGTGGTCTGA     24.008957       1
# CCTAAACTATTCGG     24.847738       1
# GAAGAATGTCCAGA     17.456129       1
# ...                      ...     ...
# CGTCGACTCTGTAG     24.381649       1
# CTAGGTGACGGGAA     19.499327       1
# GAGCTCCTGCGTAT     24.836161       1
# GTTAACCTTGGAAA     33.676941       1
# TGTTAAGAACCAGT     23.257959       1
#
# [101 rows x 15 columns]

# %%
import pandas as pd
import numpy as np

# %%
adata.obs.iloc[num]
# Out:
# perturbation                                  NaN
# read count                                    NaN
# UMI count                                     NaN
# tissue_type                             cell_line
# cell_line                                    K562
# cancer                                       True
# disease              chronic myelogenous leukemia
# perturbation_type                          CRISPR
# celltype                             lymphoblasts
# organism                                    human
# ncounts                                   16263.0
# ngenes                                       3589
# percent_mito                             6.653139
# percent_ribo                            23.513496
# nperts                                          0
# Name: TCGGTAGAATGTGC-1, dtype: object

# %%
adata.obs.loc['TCGTAGGATGGCAT']
# Out:
# perturbation                         YIPF5_pDS186
# read count                                  652.0
# UMI count                                    26.0
# tissue_type                             cell_line
# cell_line                                    K562
# cancer                                       True
# disease              chronic myelogenous leukemia
# perturbation_type                          CRISPR
# celltype                             lymphoblasts
# organism                                    human
# ncounts                                   23537.0
# ngenes                                       4628
# percent_mito                             4.626758
# percent_ribo                            23.499172
# nperts                                          2
# Name: TCGTAGGATGGCAT, dtype: object

# %%
len(adata.obs.perturbation.cat.categories)
# Out:
# 114

# %%
adata.obs['perturbation'].iloc[64295:64305]
# Out:
# cell_barcode
# TCGGTAGAAAGATG       AMIGO3_pDS434
# TCGGTAGAATGTGC-1               NaN
# TCGGTAGAGGAAAT-1               NaN
# TCGGTAGAGTACGT         SRPR_pDS482
# TCGGTAGATAGCCA       AMIGO3_pDS434
# TCGGTAGATGCAGT         SRPR_pDS482
# TCGTAGGACCCAAA        SPCS2_pDS401
# TCGTAGGAGAATCC      SEC61A1_pDS032
# TCGTAGGATGGCAT-1               NaN
# TCGTGAGAAGAGTA        COPZ1_pDS462
# Name: perturbation, dtype: category
# Categories (114, object): ['62(mod)_pBA581', '63(mod)_pBA580', '*', 'AARS_pDS381', ..., 'XRN1_pDS411', 'YIPF5_pDS001', 'YIPF5_pDS186', 'YIPF5_pDS226']

# %%
num = 64296

# %%
adata.obs['perturbation_type'].iloc[num]
# Out:
# 'CRISPR'

# %%
adata.obs['celltype']
# Out:
# 'lymphoblasts'

# %%
adata.obs['nperts'].value_counts()
# Out:
# 2    62623
# 0     2613
# 1      101
# Name: nperts, dtype: int64

# %%
adata.obs['nperts'].iloc[num]
# Out:
# 0

# %%
adata.obs['ngenes'].value_counts()
# Out:
# 3801    61
# 4010    54
# 3563    52
# 3679    50
# 3607    49
#         ..
# 5702     1
# 1492     1
# 1498     1
# 5766     1
# 1676     1
# Name: ngenes, Length: 4422, dtype: int64

# %%
adata.X
# Out:
# <65337x32738 sparse matrix of type '<class 'numpy.float32'>'
# 	with 237812947 stored elements in Compressed Sparse Column format>

# %%
from cellot.data.cell import AnnDataDataset

# %%
adata.obs.perturbation.cat.categories
# Out:
# Index(['62(mod)_pBA581', '63(mod)_pBA580', '*', 'AARS_pDS381', 'AMIGO3_pDS434',
#        'ARHGAP22_pDS458', 'ASCC3_pDS051', 'ASCC3_pDS052', 'ATF4_pBA576',
#        'ATF4_pBA577',
#        ...
#        'TTI1_pDS407', 'TTI2_pDS408', 'UFL1_pDS410', 'UFM1_pDS040',
#        'XBP1_pBA578', 'XBP1_pBA579', 'XRN1_pDS411', 'YIPF5_pDS001',
#        'YIPF5_pDS186', 'YIPF5_pDS226'],
#       dtype='object', length=114)

# %%
ds = AnnDataDataset(adata, obs='perturbation', categories=sorted(adata.obs.perturbation.cat.categories))

# %%
ds[0]
# Out:
# (<1x32738 sparse matrix of type '<class 'numpy.float32'>'
#  	with 2914 stored elements in Compressed Sparse Column format>,
#  2)

# %%
# perform PCA on the data
sc.tl.pca(adata)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 5
#       2 sc.tl.pca(adata)
#       4 # plot the scree plot
# ----> 5 sc.pl.pca_scree(adata)
#       7 # show the plot
#       8 plt.show()
#
# AttributeError: module 'scanpy.plotting' has no attribute 'pca_scree'

# %%
# Scale the data to zero mean and unit variance
# sc.pp.scale(adata, max_value=10)

# Run PCA
sc.tl.pca(adata, svd_solver='arpack')  # default svd_solver is 'auto'

# Plotting the PCA results
sc.pl.pca(adata)
# Out:
# /data/rsg/chemistry/johnyang/miniconda3/envs/cot2/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   cax = scatter(

# %%
sc.pl.pca_variance_ratio(adata)

# %%
adata.obs['perturbation_category'] = adata.obs['perturbation'].astype('category')
adata.obs['perturbation_category']
# Out:
# cell_barcode
# AAACATACAAGATG     63(mod)_pBA580
# AAACATACACCTAG        OST4_pDS353
# AAACATACTTCCCG     SEC61A1_pDS031
# AAACATTGAAACAG      EIF2B4_pDS491
# AAACATTGCAGCTA        SRPR_pDS482
#                        ...
# TTTGCATGCTTTAC       STT3A_pDS011
# TTTGCATGGAGGAC    ARHGAP22_pDS458
# TTTGCATGTAGAGA     63(mod)_pBA580
# TTTGCATGTCAAGC      KCTD16_pDS096
# TTTGCATGTGGAGG      SAMM50_pDS156
# Name: perturbation_category, Length: 65337, dtype: category
# Categories (114, object): ['62(mod)_pBA581', '63(mod)_pBA580', '*', 'AARS_pDS381', ..., 'XRN1_pDS411', 'YIPF5_pDS001', 'YIPF5_pDS186', 'YIPF5_pDS226']

# %%
sc.set_figure_params(scanpy=True, color_map='viridis')

# %%
sc.pl.pca(adata, color='perturbation_category')

# %%
adata.obs = adata.obs.fillna('nan')

# %%
adata_subset = adata[adata.obs['perturbation'].str.startswith(('ATF', 'XBP'))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 adata_subset = adata[adata.obs['perturbation'].str.startswith(('ATF', 'XBP'))]
#
# File /data/rsg/chemistry/johnyang/miniconda3/envs/cot2/lib/python3.9/site-packages/anndata/_core/anndata.py:1113, in AnnData.__getitem__(self, index)
#    1111 def __getitem__(self, index: Index) -> "AnnData":
#    1112     """Returns a sliced view of the object."""
# -> 1113     oidx, vidx = self._normalize_indices(index)
#    1114     return AnnData(self, oidx=oidx, vidx=vidx, asview=True)
#
# File /data/rsg/chemistry/johnyang/miniconda3/envs/cot2/lib/python3.9/site-packages/anndata/_core/anndata.py:1094, in AnnData._normalize_indices(self, index)
#    1093 def _normalize_indices(self, index: Optional[Index]) -> Tuple[slice, slice]:
# -> 1094     return _normalize_indices(index, self.obs_names, self.var_names)
#
# File /data/rsg/chemistry/johnyang/miniconda3/envs/cot2/lib/python3.9/site-packages/anndata/_core/index.py:35, in _normalize_indices(index, names0, names1)
#      33         index = index[0].values, index[1]
#      34 ax0, ax1 = unpack_index(index)
# ---> 35 ax0 = _normalize_index(ax0, names0)
#      36 ax1 = _normalize_index(ax1, names1)
#      37 return ax0, ax1
#
# File /data/rsg/chemistry/johnyang/miniconda3/envs/cot2/lib/python3.9/site-packages/anndata/_core/index.py:101, in _normalize_index(indexer, index)
#      99         if np.any(positions < 0):
#     100             not_found = indexer[positions < 0]
# --> 101             raise KeyError(
#     102                 f"Values {list(not_found)}, from {list(indexer)}, "
#     103                 "are not valid obs/ var names or indices."
#     104             )
#     105         return positions  # np.ndarray[int]
#     106 else:
#
# KeyError: 'Values [False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, Fa ...

# %%
import seaborn as sns

# Assuming 'adata' is your AnnData object

# Get unique perturbation categories
perturbations = adata.obs['perturbation'].cat.categories

# Create a color palette
palette = sns.color_palette('husl', n_colors=len(perturbations))

# Create a color map (dictionary) from perturbations to colors
color_map = dict(zip(perturbations, palette))

# Assign colors to perturbations
adata.uns['perturbation_colors'] = [color_map[p] for p in perturbations]

# Plot
sc.pl.pca(adata, color='perturbation')
# Out:
# /data/rsg/chemistry/johnyang/miniconda3/envs/cot2/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# 2023-08-05 16:13:01,130 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,135 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,139 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,143 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,147 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,151 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,155 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,158 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,162 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,165 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,185 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,189 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,193 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,197 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,200 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,204 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,209 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,214 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,218 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,223 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,227 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,232 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,236 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,242 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,251 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,257 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,262 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,288 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,293 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,299 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,303 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,306 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,309 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,312 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,315 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,318 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,321 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,324 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,327 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,340 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,343 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,346 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,350 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,354 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,357 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,360 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,364 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,368 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,372 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,376 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,380 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,383 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,386 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,389 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,392 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,400 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,408 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,416 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,422 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,426 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,429 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,433 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,436 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,439 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,443 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,447 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,461 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,466 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,478 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,483 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,488 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,496 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,499 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,503 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,506 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,509 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,513 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,517 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,521 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,525 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,530 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,534 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,540 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,545 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,549 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,567 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,579 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,594 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,599 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,604 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,609 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,613 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,617 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,622 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,626 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,636 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,641 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,654 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,659 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,666 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,680 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,689 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,694 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,698 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,702 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,709 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,714 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,718 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,722 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,727 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,732 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,736 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,741 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 2023-08-05 16:13:01,745 *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=50)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 65337 × 32738
#     obs: 'perturbation', 'read count', 'UMI count', 'tissue_type', 'cell_line', 'cancer', 'disease', 'perturbation_type', 'celltype', 'organism', 'ncounts', 'ngenes', 'percent_mito', 'percent_ribo', 'nperts'
#     var: 'ensembl_id', 'ncounts', 'ncells'
#     uns: 'pca', 'neighbors'
#     obsm: 'X_pca'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
adata.uns['neighbors']
# Out:
# OverloadedDict, wrapping:
# 	{'connectivities_key': 'connectivities', 'distances_key': 'distances', 'params': {'n_neighbors': 10, 'method': 'umap', 'random_state': 0, 'metric': 'euclidean', 'n_pcs': 30}}
# With overloaded keys:
# 	['connectivities', 'distances'].

# %%
import matplotlib.pyplot as plt

# %%
explained_variance_ratio = adata.uns['pca']['variance_ratio']
cumulative_variance = np.cumsum(explained_variance_ratio)

# Plot the cumulative explained variance
plt.figure(figsize=(10, 5))
plt.plot(cumulative_variance)
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance by PCA components')
plt.show()

# %%
adata.uns['pca']
# Out:
# {'params': {'zero_center': True, 'use_highly_variable': False},
#  'variance': array([117818.14   ,  21981.16   ,   9134.054  ,   8386.175  ,
#           5346.0557 ,   3760.467  ,   2927.4026 ,   2413.7146 ,
#           1843.394  ,   1483.8059 ,   1233.4078 ,   1197.9502 ,
#            851.63464,    822.0223 ,    707.8001 ,    626.3233 ,
#            530.908  ,    461.6872 ,    439.3643 ,    403.24725,
#            378.5303 ,    347.3818 ,    322.33344,    315.20212,
#            307.26843,    299.31567,    284.34363,    282.49866,
#            272.15024,    248.9595 ,    243.96628,    228.44449,
#            222.71909,    220.38629,    209.4483 ,    205.70752,
#            198.37921,    186.01907,    183.40446,    179.49297,
#            173.03105,    171.55899,    162.30057,    156.81726,
#            153.63043,    150.78796,    147.0755 ,    144.04305,
#            136.65994,    131.5064 ], dtype=float32),
#  'variance_ratio': array([0.5750176 , 0.10728019, 0.04457922, 0.04092916, 0.0260917 ,
#         0.01835315, 0.01428734, 0.01178026, 0.00899678, 0.00724179,
#         0.00601971, 0.00584666, 0.00415645, 0.00401192, 0.00345446,
#         0.0030568 , 0.00259112, 0.00225329, 0.00214434, 0.00196807,
#         0.00184744, 0.00169541, 0.00157317, 0.00153836, 0.00149964,
#         0.00146083, 0.00138775, 0.00137875, 0.00132824, 0.00121506,
#         0.00119069, 0.00111494, 0.00108699, 0.00107561, 0.00102222,
#         0.00100397, 0.0009682 , 0.00090788, 0.00089512, 0.00087602,
#         0.00084449, 0.0008373 , 0.00079212, 0.00076535, 0.0007498 ,
#         0.00073593, 0.00071781, 0.00070301, 0.00066698, 0.00064182],
#        dtype=float32)}

# %%
adata.obsm['X_pca'][63832]
# Out:
# array([-5.16183594e+02, -1.91649685e+01,  4.68456917e+01, -2.60188236e+01,
#         5.04888992e+01,  3.41604805e+01,  4.00806274e+01,  2.67554874e+01,
#        -3.72600479e+01, -4.57629728e+00, -1.05425186e+01,  2.00750828e+01,
#         7.69997168e+00, -3.89043897e-01, -2.83032322e+00, -1.67672558e+01,
#        -1.27568865e+01, -1.53989525e+01, -5.92528820e+00, -1.88404217e+01,
#         2.74292898e+00,  5.51601315e+00,  7.68805456e+00,  3.38254333e+00,
#         2.23508418e-01,  8.07301283e-01,  1.65111217e+01, -1.19262385e+00,
#        -6.46097183e-01,  7.23748159e+00,  5.05742741e+00,  2.77661419e+00,
#        -4.43314600e+00,  3.47444630e+00,  3.39852023e+00,  7.35221529e+00,
#         1.65713525e+00, -2.78500128e+00, -9.74660587e+00,  1.07632704e-01,
#         9.94420624e+00,  8.68820858e+00, -1.60969675e+00, -5.97494650e+00,
#         3.74935007e+00,  1.80668998e+00, -1.09683776e+00, -2.75785569e-02,
#         7.06748295e+00, -7.91131973e-01], dtype=float32)
